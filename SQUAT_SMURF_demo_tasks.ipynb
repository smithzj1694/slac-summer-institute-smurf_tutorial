# %% [markdown]
# # Welcome to SQUAT
#
# In this tutorial, you will work with real SQUAT frequency scan data and simulated SMuRF data to understand SQUAT dynamics and understand SQUAT parity switching measurements with SMuRF I Q data. If you have extra time, you can search for a simulated event in a SMuRF-like dataset.

# %% [markdown]
# # Prepare virtual environment
#
# To install packages into this project's vitual environment:
#
# From terminal: in your terminal, navigate to the project's directory, and type `source /.venv/bin/activate`. This command goes to the directory `/.venv/bin` and runs the script called `activate`. Now your terminal looks something like "(.venv) adroster@MV42JGWLPD SQUAT_demo % ".
#
# Now you can install packages with the typical `pip3 install [package name]`. We have prepared all the packages you need in the `requirements.txt` file in this directory. To install all of them, run `pip3 install -r requirements.txt`
#
# When you're done working on this project, deactivate the environment from terminal with the command `deactivate`.
#
# This is all true for MacOS (and probably Linux) but may be slightly different commands for Windows OS.

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
import pandas as pd

# %% [markdown]
# # Import useful functions

# %%
sys.path.append('Libraries')
from squat_simulator import *
from squat_utilities import *

# %% [markdown]
# # Part 1: What is a SQUAT
#
# In this section we will look at a single SQUAT. A SQUAT is a weakly charge-sensitive transmon qubit without a readout resonator. When energy greater than the superconducting gap energy is deposited in the device, quasiparticles are created in the superconductor. These quasiparticles tunnel across the Josephson junction, thereby changing the charge state of the qubit. This change in state can be measured, thus giving experimentalists a handle on measuring individual quasiparticles tunneling across the qubit's junction. Because the SQUAT's charge states are periodic in $2e$, we call the two visible states parity states.
#
# To characterize a SQUAT, we first scan a microwave tone over frequency and measure the response (i.e. S21). This can be accomplished with a VNA or with SMuRF. Here we load a datafile of real SQUAT data and plot it.

# %%
# Import a single SQUAT fscan data file, convert to linear complex
fn = "20260609_012659_Waymar2Q1.npz"

infile = read_file("./datafiles", fn)
phases, _ = unwrap_phases(infile, verbose=False)

freqs = infile['freqs']
qubit = infile['device'] + infile['qubit']
series = infile['series']

# - convert dB amplitude + phase -> linear complex S21
S21 = 10 ** (infile['amps'] / 20) * np.exp(1j * phases)

# %%
# Plot squat trace

def plot_vna_scan(freqs, s21, metadata=None, plot_title=None,
                  amp_db=True, savepath=None):
    """
    Plot a VNA frequency scan: amplitude vs freq, phase vs freq, and the
    IQ circle.

    Parameters
    ----------
    freqs : np.ndarray
        Frequency array in Hz.
    s21 : np.ndarray (complex)
        Complex transmission data.
    metadata : dict or None
        Optional metadata dict (from read_vna_npz) used to auto-build a title.
    plot_title : str or None
        Explicit title; overrides the metadata-derived one.
    amp_db : bool
        If True, plot amplitude in dB (20*log10|S21|); else linear magnitude.
    savepath : str or None
        If given, saves the figure to this path.

    Returns
    -------
    fig, axes
    """
    freqs_ghz = freqs / 1e9
    amp = np.abs(s21)
    amp_plot = 20 * np.log10(amp) if amp_db else amp
    phase = np.angle(s21)

    fig, axes = plt.subplots(1, 3, figsize=(16, 4.5))

    # - amplitude vs frequency
    axes[0].plot(freqs_ghz, amp_plot, color='steelblue', lw=1)
    axes[0].set_xlabel('Frequency (GHz)')
    axes[0].set_ylabel('|S21| (dB)' if amp_db else '|S21| (linear)')
    axes[0].set_title('Amplitude')

    # - phase vs frequency
    axes[1].plot(freqs_ghz, phase, color='seagreen', lw=1)
    axes[1].set_xlabel('Frequency (GHz)')
    axes[1].set_ylabel('Phase (rad)')
    axes[1].set_title('Phase')

    # - IQ circle
    axes[2].plot(s21.real, s21.imag, color='indianred', lw=1)
    axes[2].set_xlabel('I')
    axes[2].set_ylabel('Q')
    axes[2].set_title('IQ circle')
    axes[2].set_aspect('equal')

    # - title from metadata if available
    if plot_title is None and metadata is not None:
        dev = f"{metadata.get('device', '')}{metadata.get('qubit', '')}"
        ser = metadata.get('series', '')
        pwr = metadata.get('vna_power', 'N/A')
        plot_title = f"{ser}  {dev}  VNA power = {pwr} dBm"
    if plot_title:
        fig.suptitle(plot_title)

    plt.tight_layout()

    if savepath is not None:
        plt.savefig(savepath)

    return fig, axes

# %%
fig, axes = plot_vna_scan(freqs, S21, metadata=None, plot_title=None, amp_db=True, savepath=None)
plt.show()

# %% [markdown]
# Here we see the two parity states in |S21|, the two resonances in phase, and the two "blobs" in IQ space of the two resonators.

# %% [markdown]
# ### SQUAT fit equation
#
# We are fitting to the function:
#
# $$
# S_{21}(\Delta) = 1 - \frac{\Gamma_c}{2\gamma}\frac{1-i\Delta/\gamma}{1+(\Delta/\gamma)^2+(\Omega^2/\gamma\Gamma_r)}
# $$
#
# note that this function is complex.
#
# * $\Delta$ [Hz] is the detuning (angular frequency difference between qubit frequency and VNA tone).
# * $\gamma$ [Hz] is total dephasing rate of the qubit. $\gamma = \frac{1}{2}(\Gamma_c+\Gamma_\ell)+\Gamma_\phi$.
# * $\Gamma_r$ [Hz] is the total radiative decay rate. We have $\Gamma_r = \Gamma_c+\Gamma_\ell$.
# * $\Gamma_c$ [Hz] is the radiative decay to the feedline. This provides the measured signal.
# * $\Gamma_\ell$ [Hz] is the radiative decay rate to all other loss channels
# * $\Gamma_\phi$ [Hz] is the dephasing rate, accounting for phase noise (like jitter of the qubit state in the Bloch spere)
# * $\Omega$ [Hz] is the Rabi oscillation rate. We drive the qubit at this rate. It is related to the drive power parameter $\Gamma_n = \Omega^2/2\Gamma_r$
#
# ![](./images/gammas_doodle.png)

# %% [markdown]
# ### Task 1: Fit the complex data to the given fit function

# %%
# Fit the single trace

# %% [markdown]
# # Part 2: manipulating SMuRF-like IQ data, searching for an event in the data
#
# Now that we can see the SQUAT in frequency space, we can montior the SQUAT's state over time. We do this in the following way: send in a fixed tone at a frequency directly in between the SQUAT's two parity bands ("readout frequency") and measure the response of the detector over time ("timestream") at the readout frequency.
#
# In this section, you will work with simulated SQUAT data taken with SMuRF. In addition to VNA-like sweeps, SMuRF is useful for SQUAT for measuring parity switching rate by taking simultaneous timestream data on multiple SQUATs (blue is one SQUAT, orange is the other). Below you can see an image of real data taken with SMuRF, simultaneously on two SQUATs. Note that for each SQUAT, most of the signal is in the I quadrature, but some signal exists in Q.
#
# Currently, SMuRF is capable of simulatenously reading out up to 64 channels of detectors at 200 kHz per-channel streaming rate. We hope this will enable arrays of detectors (like SQUATs or MKIDs) in the near future!
#
# ![](./images/smurf-simultaneous.png)
#
# Let's simulate a timestream measurement for a single SQUAT:

# %% [markdown]
# ### Simulation parameters
#
# * duration (s): total time of the timestream
# * sampling_rate (Hz): SMuRF sample rate
# * switching_rate (Hz): SQUAT parity switching rate
# * separation (a.u.): separation in IQ space between the two parity states
# * angle (rad): angle in IQ space between the two parity states
# * dc offset (a.u.): a constant added to both states in IQ space. This models mixer leakage / cable-delay offsets seen in real data
# * snr (unitless): signal-to-noise ratio
# * seed: seed for RNG

# %%
# 2 s of data, 50 kHz sampling, 300 Hz switching.
# Two IQ blobs separated by 2.0 units along 30 degrees, SNR = 4.
t, iq, clean = generate_squat_iq_data(
    duration=2,
    sampling_rate=50_000,
    switching_rate=300,
    separation=2.0,
    angle=np.deg2rad(30),
    dc_offset=(1, 2),
    snr=4.0,
    seed=42,
)

I, Q = iq.real, iq.imag

fig, (ax_t, ax_iq) = plt.subplots(1, 2, figsize=(13, 4))

# Time-domain view: I and Q quadratures vs time.
ax_t.plot(t, I, lw=0.5, alpha=0.7, label="I")
ax_t.plot(t, Q, lw=0.5, alpha=0.7, label="Q")
#ax_t.plot(t, clean.real, "k", lw=1.0, alpha=0.6)
#ax_t.plot(t, clean.imag, "k", lw=1.0, alpha=0.6)
ax_t.set_xlabel("Time (s)")
ax_t.set_ylabel("Quadrature (a.u.)")
ax_t.set_title("I/Q timestream")
ax_t.legend()

# IQ-plane view: the two "blobs" should be visible.
ax_iq.plot(I, Q, ".", ms=1.5, alpha=0.2)
ax_iq.plot(clean.real, clean.imag, "r.", ms=8, label="state centers")
ax_iq.set_xlabel("I (a.u.)")
ax_iq.set_ylabel("Q (a.u.)")
ax_iq.set_title("IQ plane")
ax_iq.set_aspect("equal")
ax_iq.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# The above plot shows I and Q on top of each other, which may be a little confusing. Let's plot them on separate axes, like in the real SMuRF data.

# %%
fig, (ax_i, ax_q) = plt.subplots(2, 1, figsize=(12, 4))

# Time-domain view: I quadrature vs time.
ax_i.plot(t, I, lw=0.5, alpha=0.7, label="I")
# ax_i.plot(t, clean.real, "k", lw=1.0, alpha=0.6)
ax_i.set_xlabel("Time (s)")
ax_i.set_ylabel("Real(IQ) (a.u.)")
ax_i.set_title("I timestream")
ax_i.legend()

# Time-domain view: Q quadrature vs time.
ax_q.plot(t, Q, lw=0.5, alpha=0.7, label="Q")
# ax_q.plot(t, clean.imag, "k", lw=1.0, alpha=0.6)
ax_q.set_xlabel("Time (s)")
ax_q.set_ylabel("Imag(IQ) (a.u.)")
ax_q.set_title("Q timestream")
ax_q.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Great! We can clearly see the two states in I, and a little bit in Q. Let's save the data so we can operate on it.

# %%
# Save the fake data to csv
df = pd.DataFrame({"time (ms)": t * 1e3, "IQ": iq})
df.to_csv("datafiles/squat_iq_data.csv", index=False)

# %% [markdown]
# We can read in data using the following function:

# %%
times_ms, iq = load_iq_csv("datafiles/squat_iq_data.csv")

# %% [markdown]
# ### Task 2: Filter the data for better SNR
#
# Recreate the I and Q vs time plots above, but with a low-pass filter applied to I and Q. Filtering the data gives a clearer look at the switching rate.
#
# Use the Butterworth filter `butter` in `scipy.signal`.

# %%
## Filter the data using Butterworth filter
...
...
# Out:
# Ellipsis

# %%
# Plot the data
...
...
# Out:
# Ellipsis

# %% [markdown]
# # Find the optimal readout axis in IQ space
#
# We see from the above data that most of the signal is in the I quadrature. Equivalently, the two blobs in IQ space are aligned mostly along the I-axis. For optimal readout fidelity, we'd like a linear combination of I and Q, and in particular the linear combination that is along the axis in IQ space that connects the center of the two blobs (see image)
#
# ![](./images/IQ_blobs_readout.png)

# %% [markdown]
# ### Task 3: Rotate the data in IQ space such that the readout axis is along the I axis
#
# Use the Gaussian mixture model `GassuanMixture` from `sklearn.mixture` to fit the two IQ space blobs, find the vectors (in IQ space) for the center of each blob using the `means_` method. Then find the necessary rotation angle with `np.arctan2()`. Lastly, write a function that takes the raw I & Q and the rotation angle, and returns the rotated I and Q.

# %%
### need to make function similar to calc_iq_rot but outside the parity timestream class architecture

import sklearn.mixture as mix

...
...
# Out:
# Ellipsis

# %%
def rotate_iq(i, q, rotation_angle):
    ...
    return i_rot, q_rot

# %% [markdown]
# # PSD and switching rate

# %% [markdown]
# ### Task 4: PSD this telegraph signal and fit a Lorentzian to extract switching rate
#
# Here, use the `periodogram` function in `scipy.signal` to PSD the data. Let's fit this data to the appropriate function form, a Lorentzian like Eq. 14 in arXiv:2402.15471:
#
# $S_p(f) = \frac{4F^2\Gamma_p}{(2\Gamma_p)^2+(2\pi f)^2}+(1-F)^2\Delta t$.
#
# Here, $\Gamma_p$ is the parity switching rate in Hz, $F$ is the _fidelity_, $F\in[0,1]$, and $\Delta t$ is the timing resolution.
#
# You may want to experiment with the `nfft` kwarg of `periodogram`. Try `nfft = 2**12` to limit the PSD to the first ~0.1 s of data. Increasing `nfft` increases the amount of time taken into the PSD function.

# %%
# 1. Load the fake data from CSV
times_ms, iq = load_iq_csv("datafiles/squat_iq_data.csv")
i_raw, q_raw = iq.real, iq.imag

# 2. Rotate so the max-separation axis lies along I_rot

# 3. PSD directly along the max-separation axis (I_rot)

# 4. Fit a Lorentzian
# print the parity switching rate, Gamma_p
# print("Gamma_p =", fit_params['psd_corr_fit_Gamma_p'], "Hz")

# 5a. Plot the raw PSD

# 5b. Plot the PSD with the Lorentzian fit overlaid

...
...
# Out:
# Ellipsis

# %% [markdown]
# You'll notice that the fit is not the best. Generally we like to take several timestream data sets, PSD each of them, and average the PSDs. Equivalently, we can chunk the PSD into smaller segments (~0.1 s) PSD each segment, and average the PSDs.

# %%
# 2 s of data, 50 kHz sampling, 300 Hz switching.
# Two IQ blobs separated by 2.0 units along 10 degrees, SNR = 4.
# Let's do this 20 times, take PSDs, and average the PSDs.

# 1. Load the data
times_ms, iq = load_iq_csv("datafiles/squat_iq_data.csv")
i_raw, q_raw = iq.real, iq.imag

# 2. Chunk the data into 0.1 s long chunks, PSD these chunks

# 3. Average the PSDs

# 4. Fit a Lorentzian to the PSD
# print the Gamma_p
# print("Gamma_p =", fit_params['psd_corr_fit_Gamma_p'], "Hz")

# 5a. Plot the raw PSD

# 5b. Plot the PSD with the Lorentzian fit overlaid
...
...
# Out:
# Ellipsis

# %% [markdown]
# ### Task 3.1: How would this change with a low tunneling rate, like 5 Hz? How would your data taking and data processing need to change?

# %%
### Try simulating data with a switching rate of 5 Hz and chunking the timestream into 0.1 s intervals

# %% [markdown]
# # Extra time?
#
# Let's look for an event in a single timestream! Depending on energy deposition and recombination rate of the quasiparitcles, an event may look like a rapid rise in tunneling rate followed by an exponential drop-off of tunneling rate. If the tunneling rate at any point in time is greater than the sampling rate, the readout cannot resolve the two parity states and so they "blur" together.

# %%
# 50 ms of data at 50 kHz. Baseline switching 200 Hz, particle hits at 15 ms,
# event peaks at 100 kHz and decays with tau = 2.5 ms (~10 ms visible event).
t, iq, _ = generate_squat_iq_data_with_event(
    duration=0.05,
    sampling_rate=50_000,
    baseline_switching_rate=200,
    event_time=0.015,
    event_peak_rate=100e3,
    event_tau=2.5e-3,
    separation=2.0,
    angle=np.deg2rad(30),
    dc_offset=(5.0, -3.0),
    snr=6.0,
    seed=42,
)

#save data
df = pd.DataFrame({"time (ms)": t, "IQ": iq})
df.to_csv("datafiles/squat_iq_with_event_data.csv", index=False)

I, Q = iq.real, iq.imag

fig, (ax_t, ax_iq) = plt.subplots(1, 2, figsize=(13, 4))

# Time domain: watch the signal collapse toward the midpoint during the event.
ax_t.plot(t * 1e3, I, lw=0.5, alpha=0.7, label="I")
ax_t.plot(t * 1e3, Q, lw=0.5, alpha=0.7, label="Q")
ax_t.axvline(15, color="r", ls="--", lw=1, label="event")
ax_t.set_xlabel("Time (ms)")
ax_t.set_ylabel("Quadrature (a.u.)")
ax_t.set_title("I/Q timestream with particle event")
ax_t.legend()

# IQ plane: during the event, points cluster near the midpoint of the blobs.
sc = ax_iq.scatter(I, Q, c=t * 1e3, s=3, alpha=0.4, cmap="viridis")
#ax_iq.plot([z.real for z in (clean[0],)], [z.imag for z in (clean[0],)], "r.")
ax_iq.set_xlabel("I (a.u.)")
ax_iq.set_ylabel("Q (a.u.)")
ax_iq.set_title("IQ plane (color = time)")
ax_iq.set_aspect("equal")
plt.colorbar(sc, ax=ax_iq, label="Time (ms)")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 4: Chunk the data into time bins of width $\Delta t$, PSD those time bins, fit to each PSD, and plot the rate vs time.

# %%
# 1. Chunk the data into bins of witch \Delta t

# 2. PSD these shortened timestreams

# 3. Instead of averaging the PSDs, plot \Gamma_p for each chunk vs time. Can you see the event?

# %% [markdown]
# Can you see the event? Like above, you may notice that the PSD fit for these un-averaged timestreams is not the best. How would you edit the data taking or analysis routine to improve event detection?

# %%
### Your improvement code here

# %% [markdown]
# ### Task 5: Multiple SQUATS
#
# The above tasks have been for a single SQUAT. Try simulating two SQUATs simultaneously read out by SMuRF, as in the plot above at the beginning of Part 2. You can add an event in both timestreams, if you'd like. Pass both timestreams through your pipeline of rotating into the proper readout basis, chunking the data, and PSD-ing the chunks. Can you see the event in both SQUATs?

# %%
### Your multi-squat code here
